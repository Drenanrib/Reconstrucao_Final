# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import keras_tuner as kt

# %%
import os
os.chdir(r'D:\reconstrucao_estatistica_pesqueira\reconstrucao_estatistica_brasileira\RE\Reconstru--o\CLUPEIFORME')
print(os.getcwd())
# Out:
# D:\reconstrucao_estatistica_pesqueira\reconstrucao_estatistica_brasileira\RE\Reconstru--o\CLUPEIFORME

# %%
x1=pd.read_excel('propor\Manjuba_art_ind_prop.xlsx')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Renan\AppData\Local\Temp\ipykernel_20136\2737650096.py:1: SyntaxWarning: invalid escape sequence '\M'
#   x1=pd.read_excel('propor\Manjuba_art_ind_prop.xlsx')

# %%
x0 = x1[['Ano', 'Pro_ind']].dropna().values


df_x0= pd.DataFrame(x0, columns= ['Ano', 'Pro_ind'])


x = np.array(df_x0['Ano'], dtype=np.float32).reshape(-1, 1)
y = np.array(df_x0['Pro_ind'], dtype=np.float32).reshape(-1, 1)

x_mean = np.mean(x)
x_std = np.std(x)
x_normalized = (x - x_mean) / x_std

y_mean = np.mean(y)
y_std = np.std(y)
y_normalized = (y - y_mean) / y_std

# %%
def build_model(hp):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(1, activation='leaky_relu', input_shape=(1,)))
    for i in range(hp.Int('num_layers', 2, 6)):  
        model.add(tf.keras.layers.Dense(
            units=hp.Int('units_' + str(i), min_value=32, max_value=512, step=32),  
            activation='leaky_relu'
        ))

    model.add(tf.keras.layers.Dense(1, activation='leaky_relu'))
    learning_rate = hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])

  
    model.compile(
        optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),
        loss='mse',
        metrics=['mse']
    )
    
    return model

tuner = kt.RandomSearch(
    build_model,
    objective='mse', 
    max_trials=10,  
    executions_per_trial=2,  
    directory='my_tuning_dir',  
    project_name='tune_gracainha_art'
)

tuner.search(x_normalized, y_normalized, epochs=200, batch_size=12, validation_split=0.2)
# Out:
# Reloading Tuner from my_tuning_dir\tune_gracainha_art\tuner0.json

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Melhor número de camadas: {best_hps.get('num_layers')}")
for i in range(best_hps.get('num_layers')):
    print(f"Melhor número de unidades na camada {i+1}: {best_hps.get('units_' + str(i))}")
print(f"Melhor taxa de aprendizado: {best_hps.get('learning_rate')}")
# Out:
# Melhor número de camadas: 4
# Melhor número de unidades na camada 1: 480
# Melhor número de unidades na camada 2: 128
# Melhor número de unidades na camada 3: 192
# Melhor número de unidades na camada 4: 192
# Melhor taxa de aprendizado: 0.01

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(x_normalized, y_normalized, epochs=200, batch_size=12, validation_split=0.2)


x_all = np.arange(min(x.flatten()), max(x.flatten()) + 1).reshape(-1, 1)
x_all_normalized = (x_all - x_mean) / x_std
y_all_predicted_normalized = model.predict(x_all_normalized)
y_all_predicted = y_all_predicted_normalized * y_std + y_mean


df_predicted = pd.DataFrame({'Ano': x.flatten(), 'Captura Original': y.flatten()})
df_all_predicted = pd.DataFrame({'Ano': x_all.flatten(), 'Captura Preditos': y_all_predicted.flatten()})
df_combined = pd.merge(df_predicted, df_all_predicted, on='Ano', how='right').sort_values(by='Ano')

plt.scatter(df_combined['Ano'], df_combined['Captura Original'], color='blue', label='Dados originais')
plt.plot(df_combined['Ano'], df_combined['Captura Preditos'], color='red', label='Predição')
plt.xlabel('Ano')
plt.ylabel('Captura')
plt.title('Interpolação Gracainha Artesanal')
plt.legend()
plt.show()


loss_values = history.history['loss']
epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, loss_values, 'b')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.title('Loss ao longo das épocas')
plt.show()
# Out:
# Epoch 1/200
# C:\Users\Renan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.9097 - mse: 0.8435 - val_loss: 1.5104 - val_mse: 1.5104
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.4081 - mse: 1.5068 - val_loss: 1.5943 - val_mse: 1.5943
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8236 - mse: 0.8775 - val_loss: 1.5897 - val_mse: 1.5897
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.8969 - mse: 0.7728 - val_loss: 1.4646 - val_mse: 1.4646
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8600 - mse: 0.7748 - val_loss: 0.8202 - val_mse: 0.8202
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.4072 - mse: 1.3675 - val_loss: 1.5559 - val_mse: 1.5559
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.8208 - mse: 0.7957 - val_loss: 1.6468 - val_mse: 1.6468
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.8500 - mse: 0.7845 - val_loss: 1.6849 - val_mse: 1.6849
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7774 - mse: 0.8477 - val_loss: 1.8013 - val_mse: 1.8013
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.8460 - mse: 0.8347 - val_loss: 1.7521 - val_mse: 1.7521
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8408 - mse: 0.7888 - val_loss: 1.7122 - val_mse: 1.7122
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.8446 - mse: 0.7789 - val_loss: 1.7093 - val_mse: 1.7093
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7551 - mse: 0.8464 - val_loss: 1.8132 - val_mse: 1.8132
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.9871 - mse: 0.7951 - val_loss: 1.5864 - val_mse: 1.5864
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7710 - mse: 0.8611 - val_loss: 1.5898 - val_mse: 1.5898
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.7843 - mse: 0.8557 - val_loss: 1.6151 - val_mse: 1.6151
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.8738 - mse: 0.8066 - val_loss: 1.6318 - val_mse: 1.6318
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7349 - mse: 0.8760 - val_loss: 1.6678 - val_mse: 1.6678
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.7984 - mse: 0.8336 - val_loss: 1.7551 - val_mse: 1.7551
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8017 - mse: 0.8203 - val_loss: 1.7925 - val_mse: 1.7925
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8288 - mse: 0.8041 - val_loss: 1.7771 - val_mse: 1.7771
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8787 - mse: 0.7755 - val_loss: 1.6949 - val_mse: 1.6949
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7545 - mse: 0.8366 - val_loss: 1.7021 - val_mse: 1.7021
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8854 - mse: 0.7561 - val_loss: 1.6322 - val_mse: 1.6322
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8785 - mse: 0.7668 - val_loss: 1.6076 - val_mse: 1.6076
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7601 - mse: 0.8140 - val_loss: 1.6485 - val_mse: 1.6485
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.8236 - mse: 0.7777 - val_loss: 1.6658 - val_mse: 1.6658
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.7466 - mse: 0.8187 - val_loss: 1.7389 - val_mse: 1.7389
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7828 - mse: 0.7833 - val_loss: 1.7758 - val_mse: 1.7758
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.7718 - mse: 0.7777 - val_loss: 1.7368 - val_mse: 1.7368
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7002 - mse: 0.8152 - val_loss: 1.7663 - val_mse: 1.7663
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7992 - mse: 0.7745 - val_loss: 1.6900 - val_mse: 1.6900
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6538 - mse: 0.8305 - val_loss: 1.5071 - val_mse: 1.5071
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.7471 - mse: 0.7001 - val_loss: 0.6572 - val_mse: 0.6572
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.9848 - mse: 0.7637 - val_loss: 1.7565 - val_mse: 1.7565
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8661 - mse: 0.7554 - val_loss: 2.0294 - val_mse: 2.0294
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.8447 - mse: 0.7919 - val_loss: 1.9072 - val_mse: 1.9072
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.8302 - mse: 0.8765 - val_loss: 1.8233 - val_mse: 1.8233
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.9629 - mse: 0.8901 - val_loss: 1.7751 - val_mse: 1.7751
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7641 - mse: 0.8674 - val_loss: 1.8280 - val_mse: 1.8280
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7714 - mse: 0.8430 - val_loss: 2.0518 - val_mse: 2.0518
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.8121 - mse: 0.7948 - val_loss: 2.1662 - val_mse: 2.1662
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.8125 - mse: 0.8130 - val_loss: 1.9067 - val_mse: 1.9067
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7648 - mse: 0.8236 - val_loss: 1.8583 - val_mse: 1.8583
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7736 - mse: 0.7804 - val_loss: 1.7842 - val_mse: 1.7842
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7758 - mse: 0.7710 - val_loss: 1.6579 - val_mse: 1.6579
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8256 - mse: 0.7261 - val_loss: 1.1431 - val_mse: 1.1431
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.6518 - mse: 0.7045 - val_loss: 1.2104 - val_mse: 1.2104
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1610 - mse: 1.1879 - val_loss: 1.0181 - val_mse: 1.0181
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7004 - mse: 0.7177 - val_loss: 0.8394 - val_mse: 0.8394
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.8104 - mse: 0.5609 - val_loss: 0.6081 - val_mse: 0.6081
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4954 - mse: 0.4985 - val_loss: 7.8178 - val_mse: 7.8178
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9837 - mse: 1.1876 - val_loss: 0.7144 - val_mse: 0.7144
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.6008 - mse: 0.6563 - val_loss: 0.8710 - val_mse: 0.8710
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6962 - mse: 0.6584 - val_loss: 0.7209 - val_mse: 0.7209
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5767 - mse: 0.5965 - val_loss: 0.6092 - val_mse: 0.6092
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4816 - mse: 0.4267 - val_loss: 9.4540 - val_mse: 9.4540
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1908 - mse: 1.2179 - val_loss: 0.6295 - val_mse: 0.6295
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4362 - mse: 0.4971 - val_loss: 0.5440 - val_mse: 0.5440
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4102 - mse: 0.4863 - val_loss: 0.5598 - val_mse: 0.5598
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3549 - mse: 0.4030 - val_loss: 0.9462 - val_mse: 0.9462
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3788 - mse: 0.4820 - val_loss: 0.9780 - val_mse: 0.9780
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3177 - mse: 0.4060 - val_loss: 1.2762 - val_mse: 1.2762
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3018 - mse: 0.3656 - val_loss: 1.3080 - val_mse: 1.3080
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5383 - mse: 0.2976 - val_loss: 1.6591 - val_mse: 1.6591
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7299 - mse: 0.6724 - val_loss: 2.6576 - val_mse: 2.6576
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.7849 - mse: 0.6169 - val_loss: 0.7151 - val_mse: 0.7151
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6168 - mse: 0.5264 - val_loss: 0.5901 - val_mse: 0.5901
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6442 - mse: 0.5620 - val_loss: 0.7103 - val_mse: 0.7103
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5829 - mse: 0.6297 - val_loss: 0.6856 - val_mse: 0.6856
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5235 - mse: 0.6433 - val_loss: 0.5689 - val_mse: 0.5689
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5332 - mse: 0.6170 - val_loss: 0.5838 - val_mse: 0.5838
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5314 - mse: 0.5586 - val_loss: 2.9923 - val_mse: 2.9923
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.6196 - mse: 0.6196 - val_loss: 0.6148 - val_mse: 0.6148
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5476 - mse: 0.5319 - val_loss: 0.8867 - val_mse: 0.8867
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5228 - mse: 0.5894 - val_loss: 0.9531 - val_mse: 0.9531
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7832 - mse: 0.5499 - val_loss: 0.9368 - val_mse: 0.9368
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5912 - mse: 0.5515 - val_loss: 0.7151 - val_mse: 0.7151
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5015 - mse: 0.4355 - val_loss: 0.5699 - val_mse: 0.5699
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3843 - mse: 0.4496 - val_loss: 1.4367 - val_mse: 1.4367
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3728 - mse: 0.4623 - val_loss: 1.2487 - val_mse: 1.2487
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4562 - mse: 0.4022 - val_loss: 0.6685 - val_mse: 0.6685
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4207 - mse: 0.3336 - val_loss: 0.5558 - val_mse: 0.5558
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2665 - mse: 0.3311 - val_loss: 0.6395 - val_mse: 0.6395
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4114 - mse: 0.3116 - val_loss: 0.5564 - val_mse: 0.5564
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5430 - mse: 0.6541 - val_loss: 0.5515 - val_mse: 0.5515
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3406 - mse: 0.4314 - val_loss: 0.6329 - val_mse: 0.6329
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3131 - mse: 0.3866 - val_loss: 0.9954 - val_mse: 0.9954
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3576 - mse: 0.3126 - val_loss: 1.2717 - val_mse: 1.2717
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5522 - mse: 0.3753 - val_loss: 0.7737 - val_mse: 0.7737
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3427 - mse: 0.3318 - val_loss: 0.6730 - val_mse: 0.6730
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3410 - mse: 0.3340 - val_loss: 0.5558 - val_mse: 0.5558
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4551 - mse: 0.3315 - val_loss: 0.5612 - val_mse: 0.5612
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3524 - mse: 0.4158 - val_loss: 0.8725 - val_mse: 0.8725
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4001 - mse: 0.3715 - val_loss: 1.4835 - val_mse: 1.4835
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5108 - mse: 0.6350 - val_loss: 2.2391 - val_mse: 2.2391
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5545 - mse: 0.4146 - val_loss: 1.3324 - val_mse: 1.3324
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3033 - mse: 0.3724 - val_loss: 1.0401 - val_mse: 1.0401
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4553 - mse: 0.3901 - val_loss: 1.4386 - val_mse: 1.4386
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5454 - mse: 0.4375 - val_loss: 0.5252 - val_mse: 0.5252
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4554 - mse: 0.5015 - val_loss: 0.5986 - val_mse: 0.5986
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3977 - mse: 0.4969 - val_loss: 0.5439 - val_mse: 0.5439
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3793 - mse: 0.4285 - val_loss: 0.6373 - val_mse: 0.6373
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2909 - mse: 0.3668 - val_loss: 1.5218 - val_mse: 1.5218
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3578 - mse: 0.2949 - val_loss: 1.3862 - val_mse: 1.3862
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3033 - mse: 0.2678 - val_loss: 0.9821 - val_mse: 0.9821
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2555 - mse: 0.2965 - val_loss: 1.1955 - val_mse: 1.1955
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4590 - mse: 0.3360 - val_loss: 0.5154 - val_mse: 0.5154
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4801 - mse: 0.5664 - val_loss: 0.4901 - val_mse: 0.4901
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4239 - mse: 0.5481 - val_loss: 0.5485 - val_mse: 0.5485
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3913 - mse: 0.3266 - val_loss: 0.8837 - val_mse: 0.8837
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3067 - mse: 0.2928 - val_loss: 2.4413 - val_mse: 2.4413
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4511 - mse: 0.4438 - val_loss: 2.0072 - val_mse: 2.0072
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3721 - mse: 0.4407 - val_loss: 0.7169 - val_mse: 0.7169
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3547 - mse: 0.4283 - val_loss: 0.5588 - val_mse: 0.5588
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2264 - mse: 0.2637 - val_loss: 0.5672 - val_mse: 0.5672
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3492 - mse: 0.2590 - val_loss: 0.5271 - val_mse: 0.5271
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4009 - mse: 0.2477 - val_loss: 0.5317 - val_mse: 0.5317
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2509 - mse: 0.2814 - val_loss: 0.5532 - val_mse: 0.5532
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2430 - mse: 0.2775 - val_loss: 0.6691 - val_mse: 0.6691
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1713 - mse: 0.2204 - val_loss: 1.0693 - val_mse: 1.0693
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2022 - mse: 0.2048 - val_loss: 1.1903 - val_mse: 1.1903
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1640 - mse: 0.2068 - val_loss: 0.9679 - val_mse: 0.9679
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1783 - mse: 0.1821 - val_loss: 0.8401 - val_mse: 0.8401
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1768 - mse: 0.2113 - val_loss: 1.0350 - val_mse: 1.0350
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1492 - mse: 0.1918 - val_loss: 1.1364 - val_mse: 1.1364
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1508 - mse: 0.1957 - val_loss: 1.1247 - val_mse: 1.1247
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2444 - mse: 0.1776 - val_loss: 0.5629 - val_mse: 0.5629
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2309 - mse: 0.2588 - val_loss: 0.5415 - val_mse: 0.5415
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4292 - mse: 0.3331 - val_loss: 0.5346 - val_mse: 0.5346
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2808 - mse: 0.3337 - val_loss: 0.6413 - val_mse: 0.6413
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3499 - mse: 0.2220 - val_loss: 1.1617 - val_mse: 1.1617
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1826 - mse: 0.2363 - val_loss: 1.7588 - val_mse: 1.7588
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2208 - mse: 0.2582 - val_loss: 1.3372 - val_mse: 1.3372
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2106 - mse: 0.2329 - val_loss: 1.0460 - val_mse: 1.0460
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2620 - mse: 0.2478 - val_loss: 0.9716 - val_mse: 0.9716
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2675 - mse: 0.3362 - val_loss: 0.9221 - val_mse: 0.9221
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2374 - mse: 0.3067 - val_loss: 0.9327 - val_mse: 0.9327
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1861 - mse: 0.2337 - val_loss: 1.1351 - val_mse: 1.1351
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1704 - mse: 0.2180 - val_loss: 1.1702 - val_mse: 1.1702
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2645 - mse: 0.1816 - val_loss: 1.8499 - val_mse: 1.8499
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3270 - mse: 0.2272 - val_loss: 0.5445 - val_mse: 0.5445
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3800 - mse: 0.2278 - val_loss: 0.5025 - val_mse: 0.5025
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3346 - mse: 0.2367 - val_loss: 0.5428 - val_mse: 0.5428
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2723 - mse: 0.2526 - val_loss: 0.6504 - val_mse: 0.6504
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1935 - mse: 0.2494 - val_loss: 0.8933 - val_mse: 0.8933
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2215 - mse: 0.1850 - val_loss: 1.9584 - val_mse: 1.9584
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4948 - mse: 0.2638 - val_loss: 0.6566 - val_mse: 0.6566
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1733 - mse: 0.2236 - val_loss: 0.5510 - val_mse: 0.5510
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2371 - mse: 0.2909 - val_loss: 0.6063 - val_mse: 0.6063
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3272 - mse: 0.3346 - val_loss: 0.5669 - val_mse: 0.5669
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3128 - mse: 0.2631 - val_loss: 0.5367 - val_mse: 0.5367
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2134 - mse: 0.2717 - val_loss: 0.6283 - val_mse: 0.6283
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2203 - mse: 0.2072 - val_loss: 0.9694 - val_mse: 0.9694
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1936 - mse: 0.2438 - val_loss: 1.3754 - val_mse: 1.3754
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2285 - mse: 0.2573 - val_loss: 1.3592 - val_mse: 1.3592
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2186 - mse: 0.2619 - val_loss: 1.1593 - val_mse: 1.1593
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1979 - mse: 0.2450 - val_loss: 0.9883 - val_mse: 0.9883
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2198 - mse: 0.2160 - val_loss: 0.8157 - val_mse: 0.8157
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1749 - mse: 0.2201 - val_loss: 0.8046 - val_mse: 0.8046
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1720 - mse: 0.2184 - val_loss: 0.7998 - val_mse: 0.7998
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3007 - mse: 0.1650 - val_loss: 0.6312 - val_mse: 0.6312
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1754 - mse: 0.2103 - val_loss: 0.5708 - val_mse: 0.5708
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1905 - mse: 0.2347 - val_loss: 0.5712 - val_mse: 0.5712
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1896 - mse: 0.2373 - val_loss: 0.5882 - val_mse: 0.5882
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1866 - mse: 0.2318 - val_loss: 0.6696 - val_mse: 0.6696
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1773 - mse: 0.2186 - val_loss: 0.9285 - val_mse: 0.9285
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2246 - mse: 0.1965 - val_loss: 1.0924 - val_mse: 1.0924
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1951 - mse: 0.1936 - val_loss: 1.0033 - val_mse: 1.0033
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2113 - mse: 0.1919 - val_loss: 0.8463 - val_mse: 0.8463
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2483 - mse: 0.2228 - val_loss: 0.7424 - val_mse: 0.7424
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3748 - mse: 0.2141 - val_loss: 1.2960 - val_mse: 1.2960
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1866 - mse: 0.2100 - val_loss: 1.7847 - val_mse: 1.7847
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1792 - mse: 0.2227 - val_loss: 1.8503 - val_mse: 1.8503
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2234 - mse: 0.2232 - val_loss: 1.3329 - val_mse: 1.3329
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2530 - mse: 0.1840 - val_loss: 0.9866 - val_mse: 0.9866
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1881 - mse: 0.2095 - val_loss: 1.0036 - val_mse: 1.0036
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2240 - mse: 0.1709 - val_loss: 1.6459 - val_mse: 1.6459
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2155 - mse: 0.2126 - val_loss: 1.7057 - val_mse: 1.7057
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2537 - mse: 0.2822 - val_loss: 1.2408 - val_mse: 1.2408
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1973 - mse: 0.2155 - val_loss: 0.9392 - val_mse: 0.9392
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1779 - mse: 0.2189 - val_loss: 0.8437 - val_mse: 0.8437
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1725 - mse: 0.2150 - val_loss: 0.9181 - val_mse: 0.9181
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1628 - mse: 0.2070 - val_loss: 0.9620 - val_mse: 0.9620
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2136 - mse: 0.1879 - val_loss: 1.2563 - val_mse: 1.2563
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2013 - mse: 0.1999 - val_loss: 1.7863 - val_mse: 1.7863
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3408 - mse: 0.2002 - val_loss: 0.9589 - val_mse: 0.9589
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2731 - mse: 0.1438 - val_loss: 0.6281 - val_mse: 0.6281
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1728 - mse: 0.2149 - val_loss: 0.6040 - val_mse: 0.6040
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2379 - mse: 0.2083 - val_loss: 0.6327 - val_mse: 0.6327
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1756 - mse: 0.2213 - val_loss: 0.6342 - val_mse: 0.6342
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2549 - mse: 0.1842 - val_loss: 0.8023 - val_mse: 0.8023
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1853 - mse: 0.1904 - val_loss: 1.0858 - val_mse: 1.0858
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1734 - mse: 0.2040 - val_loss: 1.3622 - val_mse: 1.3622
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2042 - mse: 0.1979 - val_loss: 1.8849 - val_mse: 1.8849
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2217 - mse: 0.2274 - val_loss: 1.3530 - val_mse: 1.3530
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2125 - mse: 0.2113 - val_loss: 1.1957 - val_mse: 1.1957
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1938 - mse: 0.2135 - val_loss: 1.0081 - val_mse: 1.0081
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2774 - mse: 0.1749 - val_loss: 0.6952 - val_mse: 0.6952
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2847 - mse: 0.1556 - val_loss: 0.7245 - val_mse: 0.7245
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %%
anos_para_prever = np.array([1976, 1977]).reshape(-1, 1)
anos_para_prever_normalizados = (anos_para_prever - x_mean) / x_std
predicoes_normalizadas = model.predict(anos_para_prever_normalizados)
predicoes = predicoes_normalizadas * y_std + y_mean
predicoes = np.minimum(predicoes, 1)

for ano, predicao in zip(anos_para_prever.flatten(), predicoes.flatten()):
    print(f"Predição para o ano {ano}: {predicao}")


df_predicted = pd.DataFrame({'Ano': x.flatten(), 'Captura Original': y.flatten()})
df_all_predicted = pd.DataFrame({'Ano': x_all.flatten(), 'Captura Preditos': y_all_predicted.flatten()})
df_combined = pd.merge(df_predicted, df_all_predicted, on='Ano', how='right').sort_values(by='Ano')
df_anos_para_prever = pd.DataFrame({'Ano': anos_para_prever.flatten(), 'Captura Preditos': predicoes.flatten()})
df_combined = pd.concat([df_combined, df_anos_para_prever]).drop_duplicates().sort_values(by='Ano')


plt.scatter(df_combined['Ano'], df_combined['Captura Original'], color='blue', label='Dados originais')
plt.plot(df_combined['Ano'], df_combined['Captura Preditos'], color='red', label='Curva de Predição')
plt.scatter(df_anos_para_prever['Ano'], df_anos_para_prever['Captura Preditos'], color='green', label='Previsões', zorder=5)
plt.xlabel('Ano')
plt.ylabel('Captura')
#plt.title('Xarelete_art')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predição para o ano 1976: 1.0
# Predição para o ano 1977: 1.0

# %%
df_combined.to_excel('Prev_Proporcao_t4_Gracainha_art_.xlsx', index=False)

# %% [markdown]
# Xareu_art_ind: Desagregar 1962–1963 e 1976–1977 em Xareu_art e Xareu_ind
